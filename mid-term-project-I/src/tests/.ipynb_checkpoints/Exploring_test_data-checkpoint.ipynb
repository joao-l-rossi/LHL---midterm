# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("~/Desktop/flight_testing.csv")

# %%
test_data.head()
# Out:
#                fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2020-01-01 00:00:00                 UA       UA_CODESHARE          UA
# 1  2020-01-01 00:00:00                 UA       UA_CODESHARE          UA
# 2  2020-01-01 00:00:00                 UA       UA_CODESHARE          UA
# 3  2020-01-01 00:00:00                 DL                 DL          DL
# 4  2020-01-01 00:00:00                 DL                 DL          DL
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5475                OO   N154SY               5475
# 1                5546                OO   N166SY               5546
# 2                5552                OO   N151SY               5552
# 3                 129                DL   N319NB                129
# 4                 990                DL   N320US                990
#
#    origin_airport_id origin origin_city_name  dest_airport_id dest  \
# ...

# %%
test_data.groupby("origin").count()["fl_date"]
# Out:
# origin
# LAX    200
# Name: fl_date, dtype: int64

# %%
test_data.groupby("origin").nunique()
# Out:
#         fl_date  mkt_unique_carrier  branded_code_share  mkt_carrier  \
# origin
# LAX           8                   4                   5            4
#
#         mkt_carrier_fl_num  op_unique_carrier  tail_num  op_carrier_fl_num  \
# origin
# LAX                     44                  5       156                 44
#
#         origin_airport_id  origin  origin_city_name  dest_airport_id  dest  \
# origin
# LAX                     1       1                 1                1     1
#
#         dest_city_name  crs_dep_time  crs_arr_time  dup  crs_elapsed_time  \
# origin
# LAX                  1            51            59    1                16
#
#         flights  distance
# origin
# LAX           1         1
