# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("~/Desktop/flight_testing.csv")

# %%
test_data.head()

# %%
test_data.groupby("origin").count()["fl_date"]
# Out:
# origin
# ABE     95
# ABI     39
# ABQ    523
# ABR     14
# ABY     16
#       ...
# WRG     14
# XNA    232
# YAK     12
# YKM     27
# YUM     27
# Name: fl_date, Length: 360, dtype: int64

# %%
test_data.groupby("origin").nunique()
# Out:
#         fl_date  mkt_unique_carrier  branded_code_share  mkt_carrier  \
# origin
# ABE           7                   4                   5            4
# ABI           7                   1                   1            1
# ABQ           7                   8                  12            8
# ABR           7                   1                   1            1
# ABY           7                   1                   1            1
# ...         ...                 ...                 ...          ...
# WRG           7                   1                   1            1
# XNA           7                   4                   6            4
# YAK           6                   1                   1            1
# YKM           7                   1                   1            1
# YUM           7                   1                   1            1
#
#         mkt_carrier_fl_num  op_unique_carrier  tail_num  op_carrier_fl_num  \
# origin
# ABE                     23                  7        82                 23
# ABI                      8                  1        25                  8
# ABQ                    256                 17       418                257
# ABR                      2                  1        12                  2
# ABY                      5                  1        10                  5
# ...                    ...                ...       ...                ...
# WRG                      2                  1         6                  2
# XNA                     66                 12       175                 67
# YAK                      2                  1         9                  2
# YKM                      6                  1        19                  6
# YUM                      4                  1        14                  4
#
#         origin_airport_id  origin  ...  distance  carrier_delay  \
# origin                             ...
# ABE                     1       1  ...         9              9
# ABI                     1       1  ...         1              8
# ABQ                     1       1  ...        25             33
# ABR                     1       1  ...         1              2
# ABY                     1       1  ...         1              3
# ...                   ...     ...  ...       ...            ...
# WRG                     1       1  ...         2              4
# XNA                     1       1  ...        14             13
# YAK                     1       1  ...         2              2
# YKM                     1       1  ...         1              2
# YUM                     1       1  ...         1              2
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# origin
# ABE                 2          8               2                    8
# ABI                 9         13               2                    8
# ABQ                16         43               3                   48
# ABR                 2          2               2                    2
# ABY                 3          3               2                    3
# ...               ...        ...             ...                  ...
# WRG                 3          5               2                    3
# XNA                 4         21               3                   16
# YAK                 2          3               2                    3
# YKM                 2          4               2                    2
# YUM                 2          4               2                    5
#
#         first_dep_time  total_add_gtime  longest_add_gtime  no_name
# origin
# ABE                  1                1                  1        1
# ABI                  2                2                  2        1
# ABQ                  4                4                  4        1
# ABR                  1                1                  1        1
# ABY                  1                1                  1        1
# ...                ...              ...                ...      ...
# WRG                  1                1                  1        1
# XNA                  3                3                  3        1
# YAK                  1                1                  1        1
# YKM                  1                1                  1        1
# YUM                  1                1                  1        1
#
# [360 rows x 42 columns]
